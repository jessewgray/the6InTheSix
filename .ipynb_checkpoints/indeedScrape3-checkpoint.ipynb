# %%
import pandas as pd
from bs4 import BeautifulSoup as bs
import requests

# %%
number = 0
objList = []
for i in range(1,31):
    if i < 12:
        jobVar = 'analyst'
    elif i < 22:
        jobVar = 'engineer'
    else:
        jobVar = 'scientist'
    url = 'https://www.indeed.ca/jobs?q=data+' + jobVar + '&l=canada&start=' + str(number)
    response = requests.get(url)
    soup = bs(response.text, 'lxml')
    #print(number, i)
    number = number + 20
    
    resultList = []
    results=soup.find_all('div', class_='jobsearch-SerpJobCard')
    
    #objList = []

    for j in range(len(results)):
        jobTitle = results[j].a.text.lower()
        company = results[j].span.text.strip()
        if results[j].find('div', class_="location"):
            location = results[j].find('div', class_="location")
            location = location.text
        elif results[j].find('span', class_="location"):
            location = results[j].find('span', class_="location")
            location = location.text
        splitString = location.split(',')
        if len(splitString) < 2:
            city = splitString[0].strip()
            province = splitString[0].strip()
        else:
            city = splitString[0].strip()
            province = splitString[1].strip()
        if results[j].find('span', class_="salary"):
            salary = results[j].find('span', class_="salary")
            salary = salary.text.strip()
        else:
            salary = "n/a"
        summary = results[j].find('span', class_="summary")
        summary = summary.text.strip()
        theLink = results[0].a['href']
        theLink = "https://www.indeed.ca" + theLink
        if "analyst" in jobTitle:
            jobID = 1
        elif "engineer" in jobTitle:
            jobID = 2
        elif "scientist" in jobTitle:
            jobID = 3
        else:
            jobID = "n/a"
        obj = {
            "jobTitle": jobTitle,
            "jobID": jobID,
            "company": company,
            "city": city, 
            "province": province,
            "salary": salary,
            "summary":summary,
            "jobLink":theLink
        }
        objList.append(obj)
        resultList = []
        if number == 200:
            number = 0
#objList

# %%
indeedDF = pd.DataFrame(objList)
indeedDF
# Out:
#                city                                       company jobID  \
# 0           Concord                            Groom & Associates     1
# 1         Vancouver                                      PhotoSat     1
# 2            London                                       TD Bank     1
# 3         Newmarket                              Util-Assist Inc.     1
# 4           Burnaby                               Best Buy Canada     1
# 5           Toronto                              Remington Retail     1
# 6           Toronto                       ENVISION SALES USA INC.     1
# 7           Toronto                                 Analyticsmart     1
# 8    St. Catharines                         Niagara Health System     1
# 9         Vancouver                                       Trulioo     1
# 10         Hamilton                                      iPartner     1
# 11           Canada                                  EPAM Systems     1
# 12      Mississauga                       OSL Retail Services Inc     1
# 13          Toronto                                  Sales Beacon     1
# 14      Mississauga                      M.W.N. Technologies Inc.     1
# 15          Vaughan                                  Novitech Inc     1
# 16      Mississauga                    Peel District School Board     1
# 17           Ottawa        Canadian Security Intelligence Service     1
# 18          Toronto                                           RBC     1
# 19         Victoria                          Government of Canada     1
# 20          Toronto                                          Wave     1
# 21       North York                                Tangerine Bank     1
# 22          Toronto                                         9thCO     1
# 23          Toronto                                        Intact     1
# 24        Vancouver                                 Ritchie Bros.     1
# 25      Mississauga           HealthPRO Procurement Services Inc.     1
# 26          Concord                            Groom & Associates     1
# 27           London                                       TD Bank     1
# 28        Newmarket                              Util-Assist Inc.     1
# 29      Mississauga           HealthPRO Procurement Services Inc.     1
# ..              ...                                           ...   ...
# 765         Toronto                                     Accenture   n/a
# 766        Montréal                            Groom & Associates     3
# 767      North York  Schulich School of Business, York University     3
# 768         Toronto                                Loblaw Digital     3
# 769         Toronto                                    Boxy Charm     3
# 770         Toronto                                Loblaw Digital     3
# 771        Montréal                            Groom & Associates     3
# 772         Toronto                                       Shopify     3
# 773         Toronto                                      SickKids   n/a
# 774        Montréal                                  BrainFinance     3
# 775         Calgary                                NOVA Chemicals     3
# 776         Toronto                                          CPQI     3
# 777       Vancouver                    InMed Pharmaceuticals Inc.     3
# 778         Toronto                                       Shopify     3
# 779         Toronto                                    Amazon.com     1
# 780         Toronto                Ontario Teachers' Pension Plan     2
# 781         Burnaby                    Xenon Pharmaceuticals Inc.     3
# 782         Toronto                         BlueRock Therapeutics     3
# 783        Montréal                              Cirque du Soleil     3
# 784         Toronto                                    FreshBooks     1
# 785          Canada                           Turnstone Biologics     2
# 786          Whitby                      Thermo Fisher Scientific     3
# 787         Toronto                      Women's College Hospital     3
# 788         Calgary                Equilibrium Environmental Inc.     3
# 789         Toronto                                         CAPCO     2
# 790         Toronto                                CryptoNumerics     3
# 791       Vancouver               Northwest Hydraulic Consultants     3
# 792         Toronto                              Remington Retail   n/a
# 793        Montréal                                    SPORTLOGiQ     3
# 794      North York  Schulich School of Business, York University     3
#
#                                                jobLink  \
# 0    https://www.indeed.ca/pagead/clk?mo=r&ad=-6NYl...
# 1    https://www.indeed.ca/pagead/clk?mo=r&ad=-6NYl...
# 2    https://www.indeed.ca/pagead/clk?mo=r&ad=-6NYl...
# 3    https://www.indeed.ca/pagead/clk?mo=r&ad=-6NYl...
# 4    https://www.indeed.ca/pagead/clk?mo=r&ad=-6NYl...
# 5    https://www.indeed.ca/pagead/clk?mo=r&ad=-6NYl...
# 6    https://www.indeed.ca/pagead/clk?mo=r&ad=-6NYl...
# 7    https://www.indeed.ca/pagead/clk?mo=r&ad=-6NYl...
# 8    https://www.indeed.ca/pagead/clk?mo=r&ad=-6NYl...
# 9    https://www.indeed.ca/pagead/clk?mo=r&ad=-6NYl...
# 10   https://www.indeed.ca/pagead/clk?mo=r&ad=-6NYl...
# 11   https://www.indeed.ca/pagead/clk?mo=r&ad=-6NYl...
# 12   https://www.indeed.ca/pagead/clk?mo=r&ad=-6NYl...
# 13   https://www.indeed.ca/pagead/clk?mo=r&ad=-6NYl...
# 14   https://www.indeed.ca/pagead/clk?mo=r&ad=-6NYl...
# 15   https://www.indeed.ca/pagead/clk?mo=r&ad=-6NYl...
# 16   https://www.indeed.ca/pagead/clk?mo=r&ad=-6NYl...
# 17   https://www.indeed.ca/pagead/clk?mo=r&ad=-6NYl...
# 18   https://www.indeed.ca/pagead/clk?mo=r&ad=-6NYl...
# 19   https://www.indeed.ca/pagead/clk?mo=r&ad=-6NYl...
# 20   https://www.indeed.ca/pagead/clk?mo=r&ad=-6NYl...
# 21   https://www.indeed.ca/pagead/clk?mo=r&ad=-6NYl...
# 22   https://www.indeed.ca/pagead/clk?mo=r&ad=-6NYl...
# 23   https://www.indeed.ca/pagead/clk?mo=r&ad=-6NYl...
# 24   https://www.indeed.ca/pagead/clk?mo=r&ad=-6NYl...
# 25   https://www.indeed.ca/pagead/clk?mo=r&ad=-6NYl...
# 26   https://www.indeed.ca/pagead/clk?mo=r&ad=-6NYl...
# 27   https://www.indeed.ca/pagead/clk?mo=r&ad=-6NYl...
# 28   https://www.indeed.ca/pagead/clk?mo=r&ad=-6NYl...
# 29   https://www.indeed.ca/pagead/clk?mo=r&ad=-6NYl...
# ..                                                 ...
# 765  https://www.indeed.ca/pagead/clk?mo=r&ad=-6NYl...
# 766  https://www.indeed.ca/pagead/clk?mo=r&ad=-6NYl...
# 767  https://www.indeed.ca/pagead/clk?mo=r&ad=-6NYl...
# 768  https://www.indeed.ca/pagead/clk?mo=r&ad=-6NYl...
# 769  https://www.indeed.ca/pagead/clk?mo=r&ad=-6NYl...
# 770  https://www.indeed.ca/pagead/clk?mo=r&ad=-6NYl...
# 771  https://www.indeed.ca/pagead/clk?mo=r&ad=-6NYl...
# 772  https://www.indeed.ca/pagead/clk?mo=r&ad=-6NYl...
# 773  https://www.indeed.ca/pagead/clk?mo=r&ad=-6NYl...
# 774  https://www.indeed.ca/pagead/clk?mo=r&ad=-6NYl...
# 775  https://www.indeed.ca/pagead/clk?mo=r&ad=-6NYl...
# 776  https://www.indeed.ca/pagead/clk?mo=r&ad=-6NYl...
# 777  https://www.indeed.ca/pagead/clk?mo=r&ad=-6NYl...
# 778  https://www.indeed.ca/pagead/clk?mo=r&ad=-6NYl...
# 779  https://www.indeed.ca/pagead/clk?mo=r&ad=-6NYl...
# 780  https://www.indeed.ca/pagead/clk?mo=r&ad=-6NYl...
# 781  https://www.indeed.ca/pagead/clk?mo=r&ad=-6NYl...
# 782  https://www.indeed.ca/pagead/clk?mo=r&ad=-6NYl...
# 783  https://www.indeed.ca/pagead/clk?mo=r&ad=-6NYl...
# 784  https://www.indeed.ca/pagead/clk?mo=r&ad=-6NYl...
# 785  https://www.indeed.ca/pagead/clk?mo=r&ad=-6NYl...
# 786  https://www.indeed.ca/pagead/clk?mo=r&ad=-6NYl...
# 787  https://www.indeed.ca/pagead/clk?mo=r&ad=-6NYl...
# 788  https://www.indeed.ca/pagead/clk?mo=r&ad=-6NYl...
# 789  https://www.indeed.ca/pagead/clk?mo=r&ad=-6NYl...
# 790  https://www.indeed.ca/pagead/clk?mo=r&ad=-6NYl...
# 791  https://www.indeed.ca/pagead/clk?mo=r&ad=-6NYl...
# 792  https://www.indeed.ca/pagead/clk?mo=r&ad=-6NYl...
# 793  https://www.indeed.ca/pagead/clk?mo=r&ad=-6NYl...
# 794  https://www.indeed.ca/pagead/clk?mo=r&ad=-6NYl...
#
#                                               jobTitle province  \
# 0                 junior data analyst -water flow data       ON
# 1                               satellite data analyst       BC
# 2                                business/data analyst       ON
# 3               technical data analyst / sync operator       ON
# 4                                         data analyst       BC
# 5                                         data analyst       ON
# 6                       data analyst – excel reporting       ON
# 7                                         data analyst       ON
# 8                             data quality analyst, ft       ON
# 9                                         data analyst       BC
# 10                                data analyst advisor       ON
# 11                                 junior data analyst   Canada
# 12                                        data analyst       ON
# 13                                        data analyst       ON
# 14                              marketing data analyst       ON
# 15                  data analyst - pipeline inspection       ON
# 16                            statistical data analyst       ON
# 17                                intelligence analyst       ON
# 18                     data analyst, client onboarding       ON
# 19                                 forest data analyst       BC
# 20                       data insight analyst - growth       ON
# 21                 analyst, data science and analytics       ON
# 22                             research & data analyst       ON
# 23                  data analyst, digital distribution       ON
# 24           data management quality assurance analyst       BC
# 25         contracting / category analyst (healthcare)       ON
# 26                junior data analyst -water flow data       ON
# 27                               business/data analyst       ON
# 28              technical data analyst / sync operator       ON
# 29         contracting / category analyst (healthcare)       ON
# ..                                                 ...      ...
# 765                            data science consultant       ON
# 766                                     data scientist       QC
# 767                                     data scientist       ON
# 768                                     data scientist       ON
# 769                                     data scientist       ON
# 770                                     data scientist       ON
# 771                                     data scientist       QC
# 772       lead data scientist - app & partner platform       ON
# 773                        clin. res. project asst.-ri       ON
# 774                     senior data scientist \fintech       QC
# 775  senior research scientist (research scientist,...       AB
# 776                   data scientist - capital markets       ON
# 777        scientist, biosynthesis (12-month contract)       BC
# 778           senior data scientist- retail algorithms       ON
# 779                      business intelligence analyst       ON
# 780  intern - data scientist, data engineering & ma...       ON
# 781              research scientist, electrophysiology       BC
# 782  scientist, cell line derivation and characteri...       ON
# 783  scientifique de données principal | senior dat...       QC
# 784                      data analyst - base marketing       ON
# 785  associate scientist or engineer – manufacturin...   Canada
# 786                                     qc scientist i       ON
# 787         evaluation scientist (competition #299.18)       ON
# 788                     junior environmental scientist       AB
# 789                  cato - data engineer (consultant)       ON
# 790                                   senior scientist       ON
# 791                             hydroclimate scientist       BC
# 792           senior manager - artificial intelligence       ON
# 793                                     data scientist       QC
# 794                                     data scientist       ON
#
#                          salary  \
# 0                           n/a
# 1                           n/a
# 2                           n/a
# 3      $35,000 - $37,500 a year
# 4                           n/a
# 5             $40 - $60 an hour
# 6             $30 - $40 an hour
# 7                           n/a
# 8       $34.76 - $39.33 an hour
# 9                           n/a
# 10            $60 - $90 an hour
# 11                          n/a
# 12                          n/a
# 13                          n/a
# 14                          n/a
# 15     $40,000 - $45,000 a year
# 16                          n/a
# 17     $78,800 - $95,870 a year
# 18                          n/a
# 19     $68,891 - $82,590 a year
# 20                          n/a
# 21                          n/a
# 22                          n/a
# 23                          n/a
# 24                          n/a
# 25                          n/a
# 26                          n/a
# 27                          n/a
# 28     $35,000 - $37,500 a year
# 29                          n/a
# ..                          ...
# 765                         n/a
# 766                         n/a
# 767  $120,000 - $140,000 a year
# 768                         n/a
# 769                         n/a
# 770                         n/a
# 771                         n/a
# 772                         n/a
# 773                         n/a
# 774                         n/a
# 775     $61.76 - $89.51 an hour
# 776                         n/a
# 777                         n/a
# 778                         n/a
# 779                         n/a
# 780                         n/a
# 781                         n/a
# 782                         n/a
# 783                         n/a
# 784                         n/a
# 785                         n/a
# 786                         n/a
# 787                         n/a
# 788                         n/a
# 789                         n/a
# 790                         n/a
# 791                         n/a
# 792  $130,000 - $170,000 a year
# 793                         n/a
# 794  $120,000 - $140,000 a year
#
#                                                summary
# 0    Junior Data Analyst -water flow data. This dat...
# 1    We are looking for an entry level Satellite Da...
# 2    Provide a broad range of data analysis functio...
# 3    Reporting to the Supervisor, the Technical Dat...
# 4    As a Data Analyst you will…. The Data Analyst ...
# 5    Review, validate and manipulate data in suppor...
# 6    Excel reporting and data transformation (50%);...
# 7    Data visualization and presentation experience...
# 8    In this capacity, the Data Quality Analyst is ...
# 9    To help continue fuel our growth, we are looki...
# 10   Data Analyst Advisor*. Research and advise on ...
# 11   Collaborate with business analysts, data scien...
# 12   The Data Analyst is a skilled analytical profe...
# 13   2-5 years experience in a Data Analyst role. C...
# 14   Marketing Data Analyst. We are currently seeki...
# 15   Responsible for analyzing data collected by in...
# 16   We are currently accepting applications for a ...
# 17   The opportunity is for an indeterminate Intell...
# 18   As a data analyst working within the Client Da...
# 19   You will be working with other team members on...
# 20   Reporting to the Director, Business Intelligen...
# 21   Understand complex data networks and navigate ...
# 22   Create complex data processing pipelines. Perf...
# 23   The Data Analyst will play a critical role in ...
# 24   Reporting to the Data Management Program Manag...
# 25   Analyzes membership purchase data. Ensures acc...
# 26   Junior Data Analyst -water flow data. This dat...
# 27   Provide a broad range of data analysis functio...
# 28   Reporting to the Supervisor, the Technical Dat...
# 29   Analyzes membership purchase data. Ensures acc...
# ..                                                 ...
# 765  Familiarity with using cloud services (AWS, Go...
# 766  They are looking to add a Data Scientist to th...
# 767  The Deloitte Data Scientist is a research inte...
# 768  Develop robust, high performance streaming sol...
# 769  The Data Scientist will use a range of data sc...
# 770  Develop robust, high performance streaming sol...
# 771  They are looking to add a Data Scientist to th...
# 772  We're looking for a Lead Data Scientist to own...
# 773  Collate clinical data and correlate with brain...
# 774  Senior data scientist*. We are looking for a p...
# 775  Senior Research Scientist (Research Scientist,...
# 776  Demonstrated experience supporting big data pl...
# 777  Ability to synthesize and interpret diverse, m...
# 778  Extensive experience analyzing data using SQL....
# 779  You will be the owner of security intelligence...
# 780  Python with data processing, calculation and d...
# 781  Timely delivery of data and interpretation to ...
# 782  The Toronto, Canada site is seeking a Scientis...
# 783  Exploring new data sources; Extracting and vis...
# 784  The Opportunity – Data Analyst, Base Marketing...
# 785  Batch Analysis, data trending, and presentatio...
# 786  Karl Fisher, HPLC, GC, IR, UV/Vis, TOC, Dissol...
# 787  Opportunity as an Evaluation Scientist (Compet...
# 788  The position title is Junior Environmental Sci...
# 789  Support data scientists accessing and extracti...
# 790  We’re building an innovative machine learning ...
# 791  RealtimeTime-Series Data Management:. Experien...
# 792  Lead the planning, data collection, data analy...
# 793  As a Data Scientist, you will be a part of our...
# 794  The Deloitte Data Scientist is a research inte...
#
# [795 rows x 8 columns]

# %%
indeedDF.to_csv("./1_Extracted_Inputs/indeedCSV.csv", index = False)
