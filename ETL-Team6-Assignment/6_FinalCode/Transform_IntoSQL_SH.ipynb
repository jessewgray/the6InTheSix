# %%
import pandas as pd
from sqlalchemy import *
import pymysql
from fuzzywuzzy import fuzz
from fuzzywuzzy import process
from unidecode import unidecode
import numpy as np
# Out:
# /Users/jessegray/anaconda3/lib/python3.7/site-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
jobs=pd.read_csv('./1_Extracted_Inputs/Job_Posting_extracted_input.csv')
salaries=pd.read_csv('./1_Extracted_Inputs/Salary_extracted_input.csv')
cities=pd.read_csv('./1_Extracted_Inputs/complete_city_df.csv')
provinces_data=pd.read_csv('./1_Extracted_Inputs/province_df.csv')

provinces_data.head()
# Out:
#   province  population  private_dwellings  land_area_sqkm  \
# 0       AB   4067175.0          1654129.0       640330.37
# 1       BC   4648055.0          2063417.0       922503.15
# 2       MB   1278365.0           539748.0       552371.04
# 3       NB    747101.0           359721.0        71388.79
# 4       NL    519716.0           265739.0       370514.18
#
#    pop_density_per_sqkm  apt_mthly_rent  property_price_sqft  \
# 0              6.351682     1730.873599          3444.570786
# 1              5.038525     1956.254276          4872.388237
# 2              2.314323     1366.346154          2865.333076
# 3             10.465243     1092.149170          1338.303892
# 4              1.402689     1560.555556          3426.391042
#
#    ave_mthly_net_salary  quality_of_life_idx  cost_of_living_idx
# 0           4092.725040           170.538382           69.251325
# 1           3242.889212           180.940242           66.211790
# 2           2326.941667           147.540275           60.870704
# 3           2751.376036           173.113767           67.561323
# 4           3239.559524           160.851640           74.679354

# %%
pymysql.install_as_MySQLdb()
engine_user=input('what is your MySQL user? ')
engine_pass=input('what is you MySQL password? ')
engine = create_engine(f'mysql://{engine_user}:{engine_pass}@localhost/project_etl')
# conn=session.connection().connection
# connection=engine.connect()
# cursor=connection.cursor()
# Out:
# what is your MySQL user? root
# what is you MySQL password? snowboarding

# %% [markdown]
# # PROVINCES TABLE

# %%
#CREATE THE PROVINCES TABLE from wikipedia
wiki_tables=pd.read_html('https://en.wikipedia.org/wiki/Provinces_and_territories_of_Canada')

provinces_raw=wiki_tables[1]
provinces=provinces_raw.loc[2:11,1:2]
provinces.columns=['Province', 'Abb']

territories_raw=wiki_tables[2]
territories=territories_raw.loc[2:4,1:2]
territories.columns=['Province', 'Abb']

provinces_final=pd.merge(provinces, territories, how='outer')
#fixing Ontario name
provinces_final['Province'].loc[provinces_final['Province']=='Ontario[b]']='Ontario'

#adding Other to the Provinces List
other=pd.DataFrame(columns = ['Province','Abb'])
other.loc[0]=['Other','Other']
if 'Other' in provinces_final['Province'].values:
    pass
else:
    provinces_final=provinces_final.append(other, ignore_index=True)

#creating province_id
provinces_final['Province_ID']=provinces_final.index+1
provinces_final

#creating a province dictionary
provinces_dict=provinces_final.set_index('Abb').to_dict()['Province']

provinces_final_df=pd.merge(provinces_final, provinces_data, left_on='Abb', right_on='province', how='left')
provinces_final_df=provinces_final_df[['Province_ID', 
                    'Abb',
                    'Province',
                    'population',
                    'private_dwellings',
                    'land_area_sqkm',
                    'pop_density_per_sqkm',
                    'apt_mthly_rent',
                    'property_price_sqft',
                    'ave_mthly_net_salary',
                    'quality_of_life_idx',
                    'cost_of_living_idx']]
provinces_final_df.head()
# Out:
#    Province_ID Abb       Province  population  private_dwellings  \
# 0            1  ON        Ontario  13448494.0          5598391.0
# 1            2  QC         Quebec   8164361.0          3858943.0
# 2            3  NS    Nova Scotia    923598.0           458568.0
# 3            4  NB  New Brunswick    747101.0           359721.0
# 4            5  MB       Manitoba   1278365.0           539748.0
#
#    land_area_sqkm  pop_density_per_sqkm  apt_mthly_rent  property_price_sqft  \
# 0       908699.40             14.799717     1745.347523          4203.015516
# 1      1356625.35              6.018140     1096.028646          3337.901512
# 2        52942.33             17.445360     1295.973810          2119.426232
# 3        71388.79             10.465243     1092.149170          1338.303892
# 4       552371.04              2.314323     1366.346154          2865.333076
#
#    ave_mthly_net_salary  quality_of_life_idx  cost_of_living_idx
# 0           3403.371819           175.669800           66.349085
# 1           2880.573520           171.560877           60.485602
# 2           3228.612500           176.229324           76.419870
# 3           2751.376036           173.113767           67.561323
# 4           2326.941667           147.540275           60.870704

# %% [markdown]
# # JOB CLASS TABLE

# %%
#Job_Classification Table
job_class = {'Job_Class': ['Data Analyst', 'Data Engineer', 'Data Scientist', 'Other']}
job_class_df = pd.DataFrame(job_class)
job_class_df['Class_ID']=job_class_df.index+1
job_class_df
# Out:
#         Job_Class  Class_ID
# 0    Data Analyst         1
# 1   Data Engineer         2
# 2  Data Scientist         3
# 3           Other         4

# %% [markdown]
# # SALARIES TABLE

# %%
#raw salaries data
salaries.head()
# Out:
#    ID                                    Title Province  Annual_salary
# 0   1                 York Region Data Analyst  Ontario        85612.8
# 1   1                 York Region Data Analyst  Ontario        83574.4
# 2   1  Alliance Search Group Inc. Data Analyst  Ontario       113131.2
# 3   1       TekStaff IT Solutions Data Analyst  Ontario       100880.0
# 4   1              Infotek Direct Data Analyst  Ontario        96553.6

# %%
#fixing salaries['Province'] to match provinces_final['Province'] for clean merge

provinces_list = provinces_final['Province'].tolist()
temp_list=[]
for province in salaries['Province'].values:
    result, score = process.extractOne(province, provinces_list,scorer=fuzz.token_sort_ratio)
    temp_list.append({'Salaries Province':province, 'Province': result, 'Score':score})

provinces_fixed = pd.DataFrame(temp_list)
salaries['Province']=provinces_fixed['Province']
salaries=pd.merge(salaries, provinces_final, how='inner', on='Province')

# %%
salaries_final=salaries[['ID', 'Title', 'Annual_salary', 'Province_ID']].rename(columns={'ID': 'Class_ID',
                                                                                         'Title': 'Job_Title'})
salaries_final['salary_id']=salaries_final.index+1
salaries_final.head()
# Out:
#    Class_ID                                Job_Title  Annual_salary  \
# 0         1                 York Region Data Analyst        85612.8
# 1         1                 York Region Data Analyst        83574.4
# 2         1  Alliance Search Group Inc. Data Analyst       113131.2
# 3         1       TekStaff IT Solutions Data Analyst       100880.0
# 4         1              Infotek Direct Data Analyst        96553.6
#
#    Province_ID  salary_id
# 0            1          1
# 1            1          2
# 2            1          3
# 3            1          4
# 4            1          5

# %% [markdown]
# # PREPPING JOBS TABLE

# %%
#raw jobs data
jobs.head()
# Out:
#         city             company  jobID  \
# 0    Concord  Groom & Associates    1.0
# 1  Vancouver            PhotoSat    1.0
# 2     London             TD Bank    1.0
# 3  Newmarket    Util-Assist Inc.    1.0
# 4    Burnaby     Best Buy Canada    1.0
#
#                                              jobLink  \
# 0  https://www.indeed.ca/pagead/clk?mo=r&ad=-6NYl...
# 1  https://www.indeed.ca/pagead/clk?mo=r&ad=-6NYl...
# 2  https://www.indeed.ca/pagead/clk?mo=r&ad=-6NYl...
# 3  https://www.indeed.ca/pagead/clk?mo=r&ad=-6NYl...
# 4  https://www.indeed.ca/pagead/clk?mo=r&ad=-6NYl...
#
#                                  jobTitle province                    salary  \
# 0    junior data analyst -water flow data       ON                       NaN
# 1                  satellite data analyst       BC                       NaN
# 2                   business/data analyst       ON                       NaN
# 3  technical data analyst / sync operator       ON  $35,000 - $37,500 a year
# 4                            data analyst       BC                       NaN
#
#                                              summary
# 0  Junior Data Analyst -water flow data. This dat...
# 1  We are looking for an entry level Satellite Da...
# 2  Provide a broad range of data analysis functio...
# 3  Reporting to the Supervisor, the Technical Dat...
# 4  As a Data Analyst you will…. The Data Analyst ...

# %%
#remove accents from french cities in jobs table
for i, row in jobs.iterrows():
    jobs.loc[i,'city']=(unidecode(row['city']))

# %%
#finding cities that are in jobs table but not in city table
missing_job_cities=[]
for i in jobs['city'].values:
    if i in cities['city_name'].values:
        pass
    else:
        missing_job_cities.append(i)

cities_jobs_missing=set(missing_job_cities)
cities_jobs_missing
# Out:
# {'Bedford',
#  'Canada',
#  'Concord',
#  'Engineer',
#  'Etobicoke',
#  'Georgetown',
#  'Greater Toronto Area',
#  'High Prairie',
#  'Langford',
#  'Lower Mainland',
#  'Metro Vancouver Regional District',
#  'National Capital Region',
#  'North Saanich',
#  'North York',
#  'Ontario',
#  'Penetanguishene',
#  'Pitt Meadows',
#  'Remote',
#  'Repulse Bay',
#  'Saint-Hyacinthe',
#  'Saint-Laurent',
#  'Saskatchewan',
#  'Sidney',
#  'Smiths Falls',
#  'Sparwood',
#  'St. Catharines',
#  'Stoney Creek',
#  'Thornhill',
#  'Wood Buffalo'}

# %%
#use string matching to match city names between jobs table and city table with cut off score of 80
temp_list=[]
city_list=cities['city_name'].tolist()
for city in cities_jobs_missing:
    try:
        result, score = process.extractOne(city, city_list,scorer=fuzz.token_set_ratio, score_cutoff=80)
        temp_list.append({'Job Table City':city, 'City Table City': result, 'Score':score})
    except:
        pass
cities_fixed = pd.DataFrame(temp_list)
cities_fixed
# Out:
#      City Table City                     Job Table City  Score
# 0          Vancouver  Metro Vancouver Regional District    100
# 1  Fort Saskatchewan                       Saskatchewan    100
# 2     St. Catherines                     St. Catharines     92
# 3            Toronto               Greater Toronto Area    100
# 4            Saanich                      North Saanich    100
# 5             Sydney                             Sidney     83

# %%
city_corrections=cities_fixed.set_index('Job Table City').to_dict()['City Table City']
city_corrections
keys = ['Greater Toronto Area', 'Metro Vancouver Regional District', 'North Saanich', 'St. Catharines', 'Sidney']
city_corrections_complete = {x:city_corrections[x] for x in keys}
city_corrections_complete
# Out:
# {'Greater Toronto Area': 'Toronto',
#  'Metro Vancouver Regional District': 'Vancouver',
#  'North Saanich': 'Saanich',
#  'St. Catharines': 'St. Catherines',
#  'Sidney': 'Sydney'}

# %%
#replacing job table cities based on the city_corrections_complete dictionary 
for k,v in city_corrections_complete.items():
    jobs['city'].loc[jobs['city']==k] = v
# Out:
# /Users/jessegray/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
#finding cities that are still in jobs table but not in city table and label them as 'Other'
for i, row in jobs.iterrows():
    if jobs.loc[i,'city'] in cities['city_name'].values:
        pass
    else:
        jobs.loc[i,'city']='Other'

# %%
#replace any Nan in jobID(Class_ID) column with 4 (indicates 'Other')
jobs['jobID'].fillna(4, inplace=True)

# %%
#fixing the provinces in jobs table using fuzzy wuzzy (must have partial ratio score of 100)
provinces_jobs = jobs['province'].unique()
provinces_abbs = provinces_final['Abb'].tolist()
temp_list=[]
for province in provinces_jobs:
    try:
        result, score = process.extractOne(province, provinces_abbs,scorer=fuzz.partial_ratio, score_cutoff=100)
        temp_list.append({'Job Table Province':province, 'Province': result, 'Score':score})
    except:
        pass
provinces_fixed = pd.DataFrame(temp_list)

#creating a dictionary for province corrections
province_corrections=provinces_fixed.set_index('Job Table Province').to_dict()['Province']

#replace provinces in jobs table based on province_corrrections dictionary
for k,v in province_corrections.items():
    jobs['province'].loc[jobs['province']==k] = v
# Out:
# /Users/jessegray/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
jobs.shape
# Out:
# (795, 8)

# %% [markdown]
# # CITIES TABLE

# %%
#raw city data
cities.head()
# Out:
#    city_id        city_name   longitude   latitude          orig_city_name  \
# 0    33365  North Vancouver -123.072414  49.319982         North Vancouver
# 1    33399         Cochrane -114.467860  51.190988                Cochrane
# 2    33600       Slave Lake -114.771118  55.286683              Slave Lake
# 3    33745        Tottenham  -79.805595  44.022484           Tottenham, ON
# 4    33754       Boisbriand  -73.838373  45.612634  Boisbriand, QC, Canada
#
#   prov_from_name             name   type     province_name  population  \
# 0            NaN  North Vancouver   City  British Columbia     52898.0
# 1            NaN         Cochrane   Town           Alberta     25853.0
# 2            NaN       Slave Lake   Town           Alberta      6651.0
# 3             ON              NaN    NaN               NaN         NaN
# 4             QC       Boisbriand  Ville            Quebec     26884.0
#
#    private_dwellings  land_area_sqkm  pop_density_per_sqkm province  \
# 0            26426.0           11.85                4465.1       BC
# 1            10225.0           29.83                 866.7       AB
# 2             2762.0           14.44                 460.5       AB
# 3                NaN             NaN                   NaN       ON
# 4            10537.0           27.82                 966.5       QC
#
#    apt_mthly_rent  property_price_sqft  ave_mthly_net_salary  \
# 0          3805.0           9592.89513           4750.000000
# 1          2400.0                  NaN           2250.000000
# 2          2200.0                  NaN           4958.333333
# 3             NaN                  NaN                   NaN
# 4             NaN                  NaN           3916.500000
#
#    quality_of_life_idx  cost_of_living_idx
# 0                  NaN                 NaN
# 1                  NaN                 NaN
# 2                  NaN                 NaN
# 3                  NaN                 NaN
# 4                  NaN                 NaN

# %%
#finding citites that are in job table but not in city table 

missing_job_cities=[]
for i in jobs['city'].values:
    if i in cities['city_name'].values:
        pass
    else:
        missing_job_cities.append(i)

cities_jobs_missing=set(missing_job_cities)
cities_jobs_missing
# Out:
# {'Other'}

# %%
#adding 'Other' as city to city table
columns=cities.columns
df_temp=pd.DataFrame(columns=columns)
df_temp = df_temp.append(pd.Series([np.nan]), ignore_index=True)
df_temp['city_name'] = 'Other'
df_temp['province']='Other'
if 'Other' in cities['city_name'].values:
    pass
else:
    cities = cities.append(df_temp, ignore_index=True, sort=False)
    
cities
# Out:
#     city_id                city_name   longitude   latitude  \
# 0     33365          North Vancouver -123.072414  49.319982
# 1     33399                 Cochrane -114.467860  51.190988
# 2     33600               Slave Lake -114.771118  55.286683
# 3     33745                Tottenham  -79.805595  44.022484
# 4     33754               Boisbriand  -73.838373  45.612634
# 11                                  Brockville, Ont             ON
# 12                                  Holland Landing            NaN
# 13                                         Yarmouth            NaN
# 14                                          Lachute            NaN
# 15                                       Fort Smith            NaN
# 16                                      Mount Pearl            NaN
# 17                                   Drumheller, AB             AB
# 18                                Arnprior, Ontario             ON
# 19                                          Camrose            NaN
# 20                             Bowmanville, Ontario             ON
# 21                                     Barrrhead AB            NaN
# 22                                           Tofino            NaN
# 23                                      Watson Lake            NaN
# 24                                Chartierville, QC             QC
# 25                                       Kindersley            NaN
# 26                                        Ennismore            NaN
# 27                                          Okotoks            NaN
# 28                            Fort Frances, Ontario             ON
# 29   Sainte-Agathe-des-Monts (Ste-Agathe des Monts)            NaN
# ..                                              ...            ...
# 242                                      Shawinigan            NaN
# 243                                   Port Colborne            NaN
# 244                                     Orangeville            NaN
# 245                                          Inuvik            NaN
# 246                                      Fernie, BC             BC
# 247                                           Truro            NaN
# 248                                     Auclair, QC             QC
# 249                                 Beaverlodge, AB             AB
# 250                                    Caroline, AB             AB
# 251                                   Castlegar, BC             BC
# 252                                Deschambault, QC             QC
# 253                                          Dorset            NaN
# 254                                     Ferme Neuve            NaN
# 255                                       Flin Flon            NaN
# 256                                     Fort Mackay            NaN
# 257                                      Grand Bend            NaN
# 258                                     Grand Falls            NaN
# 259                                            Hope            NaN
# 260                                         Houston            NaN
# 261                                         La Dore            NaN
# 262                                       La Patrie            NaN
# 263                                        La Peche            NaN
# 264                                     Parry Sound            NaN
# 265                                 Port Hawkesbury            NaN
# 266                                    Port Stanley            NaN
# 267                                         Quesnel            NaN
# 268                                      Senneterre            NaN
# 269                                     The Pas, MB             MB
# 270                                 Meadow Lake, SK             SK
# 271                                             NaN            NaN
#
#                         name                        type  \
# 0            North Vancouver                        City
# 1                   Cochrane                        Town
# 2                 Slave Lake                        Town
# 3                        NaN                         NaN
# 4                 Boisbriand                       Ville
# 5                 Leamington                Municipality
# 6              Drummondville                       Ville
# 7                 Summerland       District municipality
# 8                  Armstrong                        City
# 9                   Marathon                        Town
# 10                       NaN                         NaN
# 11                Brockville                        City
# 12                       NaN                         NaN
# 13                  Yarmouth                        Town
# 14                   Lachute                       Ville
# 15                Fort Smith                        Town
# 16               Mount Pearl                        City
# 17                Drumheller                        Town
# 18                  Arnprior                        Town
# 19                   Camrose                        City
# 20                       NaN                         NaN
# 21                  Barrhead                        Town
# 22                    Tofino       District municipality
# 23               Watson Lake                        Town
# 24             Chartierville                Municipalité
# 25                Kindersley                        Town
# 26                       NaN                         NaN
# 27                   Okotoks                        Town
# 28              Fort Frances                        Town
# 29   Sainte-Agathe-des-Monts                       Ville
# ..                       ...                         ...
# 242               Shawinigan                       Ville
# 243            Port Colborne                        City
# 244              Orangeville                        Town
# 245                   Inuvik                        Town
# 246                   Fernie                        City
# 247                    Truro                        Town
# 248                  Auclair                Municipalité
# 249              Beaverlodge                        Town
# 250                 Caroline                     Village
# 251                Castlegar                        City
# 252   Deschambault-Grondines                Municipalité
# 253                      NaN                         NaN
# 254              Ferme-Neuve                Municipalité
# 255                Flin Flon                        City
#        'pop_density_per_sqkm',             'province',       'apt_mthly_rent',
#         'property_price_sqft', 'ave_mthly_net_salary',  'quality_of_life_idx',
#          'cost_of_living_idx',                      0,             'Province',
#                         'Abb',          'Province_ID'],
#       dtype='object')

# %%
cities.head()
# Out:
#    city_id        city_name   longitude   latitude          orig_city_name  \
# 0        1  North Vancouver -123.072414  49.319982         North Vancouver
# 1        2         Cochrane -114.467860  51.190988                Cochrane
# 2        3       Slave Lake -114.771118  55.286683              Slave Lake
# 3        4        Tottenham  -79.805595  44.022484           Tottenham, ON
# 4        5       Boisbriand  -73.838373  45.612634  Boisbriand, QC, Canada
#
#   prov_from_name             name   type     province_name  population  \
# 0            NaN  North Vancouver   City  British Columbia     52898.0
# 1            NaN         Cochrane   Town           Alberta     25853.0
# 2            NaN       Slave Lake   Town           Alberta      6651.0
# 3             ON              NaN    NaN               NaN         NaN
# 4             QC       Boisbriand  Ville            Quebec     26884.0
#
#       ...       province  apt_mthly_rent  property_price_sqft  \
# 0     ...             BC          3805.0           9592.89513
# 1     ...             AB          2400.0                  NaN
# 2     ...             AB          2200.0                  NaN
# 3     ...             ON             NaN                  NaN
# 4     ...             QC             NaN                  NaN
#
#   ave_mthly_net_salary  quality_of_life_idx  cost_of_living_idx   0  \
# 0          4750.000000                  NaN                 NaN NaN
# 1          2250.000000                  NaN                 NaN NaN
# 2          4958.333333                  NaN                 NaN NaN
# 3                  NaN                  NaN                 NaN NaN
# 4          3916.500000                  NaN                 NaN NaN
#
#            Province  Abb  Province_ID
# 0  British Columbia   BC          6.0
# 1           Alberta   AB          9.0
# 2           Alberta   AB          9.0
# 3           Ontario   ON          1.0
# 4            Quebec   QC          2.0
#
# [5 rows x 23 columns]

# %%
cities_final=cities[['city_id',
                     'city_name',
                     'type',
                     'Province_ID',
                     'population',
                     'pop_density_per_sqkm',
                     'property_price_sqft',
                     'cost_of_living_idx',
                     'private_dwellings',
                     'ave_mthly_net_salary',
                     'land_area_sqkm',
                     'apt_mthly_rent',
                     'quality_of_life_idx']]

cities_final.head()
# Out:
#    city_id        city_name   type  Province_ID  population  \
# 0        1  North Vancouver   City          6.0     52898.0
# 1        2         Cochrane   Town          9.0     25853.0
# 2        3       Slave Lake   Town          9.0      6651.0
# 3        4        Tottenham    NaN          1.0         NaN
# 4        5       Boisbriand  Ville          2.0     26884.0
#
#    pop_density_per_sqkm  property_price_sqft  cost_of_living_idx  \
# 0                4465.1           9592.89513                 NaN
# 1                 866.7                  NaN                 NaN
# 2                 460.5                  NaN                 NaN
# 3                   NaN                  NaN                 NaN
# 4                 966.5                  NaN                 NaN
#
#    private_dwellings  ave_mthly_net_salary  land_area_sqkm  apt_mthly_rent  \
# 0            26426.0           4750.000000           11.85          3805.0
# 1            10225.0           2250.000000           29.83          2400.0
# 2             2762.0           4958.333333           14.44          2200.0
# 3                NaN                   NaN             NaN             NaN
# 4            10537.0           3916.500000           27.82             NaN
#
#    quality_of_life_idx
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN

# %% [markdown]
# # FINALIZING JOBS TABLE

# %%
jobs.head()
# Out:
#         city             company  jobID  \
# 0      Other  Groom & Associates    1.0
# 1  Vancouver            PhotoSat    1.0
# 2     London             TD Bank    1.0
# 3  Newmarket    Util-Assist Inc.    1.0
# 4    Burnaby     Best Buy Canada    1.0
#
#                                              jobLink  \
# 0  https://www.indeed.ca/pagead/clk?mo=r&ad=-6NYl...
# 1  https://www.indeed.ca/pagead/clk?mo=r&ad=-6NYl...
# 2  https://www.indeed.ca/pagead/clk?mo=r&ad=-6NYl...
# 3  https://www.indeed.ca/pagead/clk?mo=r&ad=-6NYl...
# 4  https://www.indeed.ca/pagead/clk?mo=r&ad=-6NYl...
#
#                                  jobTitle province                    salary  \
# 0    junior data analyst -water flow data       ON                       NaN
# 1                  satellite data analyst       BC                       NaN
# 2                   business/data analyst       ON                       NaN
# 3  technical data analyst / sync operator       ON  $35,000 - $37,500 a year
# 4                            data analyst       BC                       NaN
#
#                                              summary
# 0  Junior Data Analyst -water flow data. This dat...
# 1  We are looking for an entry level Satellite Da...
# 2  Provide a broad range of data analysis functio...
# 3  Reporting to the Supervisor, the Technical Dat...
# 4  As a Data Analyst you will…. The Data Analyst ...

# %%
#adding job_id
jobs['job_id'] = jobs.index + 1

# %%
#merging the jobs table with provinces and job_class
jobs_final=pd.merge(jobs, provinces_final, left_on='province', right_on='Abb', how='inner')
jobs_final=pd.merge(jobs_final, job_class_df, left_on='jobID', right_on='Class_ID', how='inner')

# merging job table with city table on city and province
jobs_final=pd.merge(jobs_final, cities, left_on=['city', 'Province_ID'] , right_on=['city_name', 'Province_ID'], how='inner')


jobs_final.columns
jobs_final=jobs_final[['job_id', 'jobTitle', 'Class_ID', 'Province_ID', 'city_id', 'company', 'summary']]
#resetting job_id
jobs_final['job_id']=jobs_final.index+1

# %%
jobs_final
# Out:
#      job_id                                 jobTitle  Class_ID  Province_ID  \
# 0         1                    business/data analyst         1            1
# 1         2                    business/data analyst         1            1
# 2         3                    business/data analyst         1            1
# 3         4                    business/data analyst         1            1
# 4         5                    business/data analyst         1            1
# 5         6                    business/data analyst         1            1
# 6         7                    business/data analyst         1            1
# 7         8                    business/data analyst         1            1
# 8         9                    business/data analyst         1            1
# 9        10              quantitative equity analyst         1            1
# 10       11                    business/data analyst         1            1
# 11       12                    business/data analyst         1            1
# 12       13                    business/data analyst         1            1
# 13       14   technical data analyst / sync operator         1            1
# 14       15   technical data analyst / sync operator         1            1
# 15       16   technical data analyst / sync operator         1            1
# 16       17   technical data analyst / sync operator         1            1
# 17       18   technical data analyst / sync operator         1            1
# 18       19   technical data analyst / sync operator         1            1
# 19       20   technical data analyst / sync operator         1            1
# 20       21   technical data analyst / sync operator         1            1
# 21       22   technical data analyst / sync operator         1            1
# 22       23   technical data analyst / sync operator         1            1
# 23       24   technical data analyst / sync operator         1            1
# 24       25   technical data analyst / sync operator         1            1
# 25       26                       packaging engineer         2            1
# 26       27                             data analyst         1            1
# 27       28           data analyst – excel reporting         1            1
# 28       29                             data analyst         1            1
# 29       30                             data analyst         1            1
# ..      ...                                      ...       ...          ...
# 689     690             product development engineer         2            7
# 690     691                  health research analyst         1           12
# 691     692                 business data technician         4            4
# 692     693                           data scientist         3            1
# 693     694                    senior data scientist         3            1
# 694     695  computer vision data research scientist         3            1
# 695     696                        big data engineer         2            1
# 696     697                            data engineer         2            1
# 697     698                            data engineer         2            1
# 698     699                data scientist internship         3            1
# 699     700                  r&d scientist (sensors)         3            1
# 700     701                    scientist/bioengineer         2            1
# 701     702                           data scientist         3            1
# 702     703         data scientist co-op apply today         3            1
# 703     704                            data engineer         2            1
# 704     705      bioinformatics researcher/scientist         3            1
# 705     706                           food scientist         3            1
# 706     707              bioprocess scientist (lead)         3            1
# 707     708        data scientist (machine learning)         3            6
# 708     709                 quality engineer - paint         2            1
# 709     710                      mechanical engineer         2            1
# 710     711                            data engineer         2            6
# 711     712                            data engineer         2            6
# 712     713                     senior data engineer         2            6
# 713     714    junior air quality engineer/scientist         2            6
# 714     715                    data science engineer         2            6
# 715     716                        research engineer         2            6
# 716     717                    construction engineer         2           10
# 717     718                    construction engineer         2           10
# 718     719          continuous improvement engineer         2           11
#
#      city_id                                    company  \
# 0         55                                    TD Bank
# 1         55                                    TD Bank
# 2         55                                    TD Bank
# 3         55                                    TD Bank
# 4         55                                    TD Bank
# 5         55                                    TD Bank
# 6         55                                    TD Bank
# 7         55                                    TD Bank
# 8         55                                    TD Bank
# 9         55                            Great West Life
# 10        55                                    TD Bank
# 11        55                                    TD Bank
# 12        55                                    TD Bank
# 13       161                           Util-Assist Inc.
# 14       161                           Util-Assist Inc.
# 15       161                           Util-Assist Inc.
# 16       161                           Util-Assist Inc.
# 17       161                           Util-Assist Inc.
# 18       161                           Util-Assist Inc.
# 19       161                           Util-Assist Inc.
# 20       161                           Util-Assist Inc.
# 21       161                           Util-Assist Inc.
# 22       161                           Util-Assist Inc.
# 23       161                           Util-Assist Inc.
# 24       161                           Util-Assist Inc.
# 25       161               Magna Mechatronics & Mirrors
# 26        73                           Remington Retail
# 27        73                    ENVISION SALES USA INC.
# 28        73                              Analyticsmart
# 29        73                               Sales Beacon
# ..       ...                                        ...
# 689      118                  Reliatar Technologies LTD
# 690      107                           Yukon Government
# 691       59                         Medavie Blue Cross
# 692       53                                     EMAGIN
# 693       53                                     Primal
# 694       53                                  Miovision
# 695       53                           Clairvoyant Inc.
# 696       53                             Index Exchange
# 697       53                              Dialpad, Inc.
# 698      129                                    INVISTA
# 699      129                        LaserDepth Dynamics
# 700      129                       Lonza/Octane Biotech
# 701       42                               Prodigy Game
# 702       42                                     Kalder
# 703       42                               Prodigy Game
# 704       90                                   Noblegen
# 705       90                                   Noblegen
# 706      128                  Province Brands of Canada
# 707      220                        Finger Food Studios
# 708       77                  Fiat Chrysler Automobiles
# 709       31                            Sle-Co Plastics
# 710       66                                    Epicure
# 711        1                                       ICBC
# 712        1  Insurance Corporation of British Columbia
# 713        1                   Envirochem Services Inc.
# 714      261                        Pason Systems Corp.
# 715       46                        SewerVUE Technology
# 716       67                Weir's Construction Limited
# 717      182                Weir's Construction Limited
# 718      116                                  Rio Tinto
#
#                                                summary
# 0    Provide a broad range of data analysis functio...
# 1    Provide a broad range of data analysis functio...
# 2    Provide a broad range of data analysis functio...
# 3    Provide a broad range of data analysis functio...
# 4    Provide a broad range of data analysis functio...
# 5    Provide a broad range of data analysis functio...
# 6    Provide a broad range of data analysis functio...
# 7    Provide a broad range of data analysis functio...
# 8    Provide a broad range of data analysis functio...
# 9    Incorporate new data feeds into the database f...
# 10   Provide a broad range of data analysis functio...
# 11   Provide a broad range of data analysis functio...
# 12   Provide a broad range of data analysis functio...
# 13   Reporting to the Supervisor, the Technical Dat...
# 14   Reporting to the Supervisor, the Technical Dat...
# 15   Reporting to the Supervisor, the Technical Dat...
# 16   Reporting to the Supervisor, the Technical Dat...
# 17   Reporting to the Supervisor, the Technical Dat...
# 18   Reporting to the Supervisor, the Technical Dat...
# 19   Reporting to the Supervisor, the Technical Dat...
# 20   Reporting to the Supervisor, the Technical Dat...
# 21   Reporting to the Supervisor, the Technical Dat...
# 22   Reporting to the Supervisor, the Technical Dat...
# 23   Reporting to the Supervisor, the Technical Dat...
# 24   Reporting to the Supervisor, the Technical Dat...
# 25   POSITION OVERVIEW This position is accountable...
# 26   Review, validate and manipulate data in suppor...
# 27   Excel reporting and data transformation (50%);...
# 28   Data visualization and presentation experience...
# 29   2-5 years experience in a Data Analyst role. C...
# ..                                                 ...
# 689  Product testing and data analysis solution. Da...
# 690  Applied technical knowledge and skill in quant...
# 691  Business Data Technician. The engineers of our...
# 692  In short, we’re looking for impact-minded soft...
# 693  Write production code with our developers and ...
# 694  Creating data visualizations and analyzing dat...
# 695  Big Data Engineer:. Big Data / Hadoop Engineer...
# 696  Working within our larger R&D team, our Data E...
# 697  We're looking for data engineers who are eager...
# 698  Position Summary – Data Scientist Internship. ...
# 699  Working knowledge of data acquisition software...
# 700  The Scientist will be responsible for acquirin...
# 701  Demonstrated ability to do data science, data ...
# 702  Drive the collection of new data and refine ex...
# 703  Collaborate with data architects, data strateg...
# 704  Provide scientific input for bioinformatics, d...
# 705  Organizing technical data and provide oral pre...
# 706  Expertise in compiling data, statistical analy...
# 707  Work with clients to evaluate big data problem...
# 708  From a proactive standpoint, the Quality Engin...
# 709  Organize data and upload Maintenance Data data...
# 710  As a Senior Data Engineer you will:. Epicure i...
# 711  The Data Engineer will join the Information Ma...
# 712  Senior Data Engineer. Strong data quality mana...
# 713  Proven ability in data analysis and interpreta...
# 714  Passion for learning and implementing data ana...
# 715  We have an opportunity for a Research Engineer...
# 716  Data analysis software; Mapping and data visua...
# 717  Data analysis software; Mapping and data visua...
# 718  Continuous Improvement Engineer. Assists in ga...
#
# [719 rows x 7 columns]

# %% [markdown]
# # LOADING DATAFRAMES TO SQL

# %%
job_class_df.to_sql('job_class', con=engine, if_exists='replace', index=False)
engine.execute('ALTER TABLE `job_class` ADD PRIMARY KEY (`Class_ID`);')
provinces_final_df.to_sql('provinces', con=engine, if_exists='replace', index=False)
engine.execute('ALTER TABLE `provinces` ADD PRIMARY KEY (`Province_ID`);')
salaries_final.to_sql('salaries', con=engine, if_exists='replace', index=False)
engine.execute('ALTER TABLE `salaries` ADD PRIMARY KEY (`salary_id`);')
jobs_final.to_sql('jobs', con=engine, if_exists='replace', index=False)
engine.execute('ALTER TABLE `jobs` ADD PRIMARY KEY (`job_id`);')
cities_final.to_sql('cities', con=engine, if_exists='replace', index=False)
engine.execute('ALTER TABLE `cities` ADD PRIMARY KEY (`city_id`);')
